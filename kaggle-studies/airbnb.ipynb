# %%
# Bibliotecas Públicas
import numpy as np
import pandas as pd

# %%
airbnb = pd.read_csv("https://drive.google.com/u/0/uc?id=1SILFvyfG1IzM9OEh7MIX5v_HCNr3GpEw&export=download", low_memory=False)
airbnb.head(100)
# Out:
#                              city   longitude   latitude  \
# 0                          Coogee  151.253102 -33.915035
# 1                     Chippendale  151.202260 -33.884258
# 2   Council of the City of Sydney  151.203609 -33.910015
# 3                     Bondi Beach  151.271400 -33.883456
# 4                     North Bondi  151.275143 -33.883958
# ..                            ...         ...        ...
# 95                        Kogarah  151.134949 -33.964974
# 96                        Pyrmont  151.196448 -33.870403
# 97                      Roseville  151.189254 -33.780033
# 98                    Bondi Beach  151.271168 -33.892324
# 99                      Petersham  151.163941 -33.889632
#
#     review_scores_rating  number_of_reviews  minimum_nights  security_deposit  \
# 0              93.412413                  0               5                 0
# 1              90.000000                 48               1               300
# ...

# %%
missing_values = airbnb.isnull().sum()
missing_values
# Out:
# city                      0
# longitude                 0
# latitude                  0
# review_scores_rating      0
# number_of_reviews         0
# minimum_nights            0
# security_deposit          0
# cleaning_fee              0
# accommodates              0
# bathrooms                 0
# bedrooms                  0
# beds                      0
# property_type             0
# room_type                 0
# availability_365          0
# host_identity_verified    0
# host_is_superhost         0
# cancellation_policy       0
# price                     0
# dtype: int64

# %%
airbnb.info()
# Out:
#           longitude      latitude  ...  host_is_superhost         price
# count  10000.000000  10000.000000  ...       10000.000000  10000.000000
# mean     151.210939    -33.861957  ...           0.127400    207.716700
# std        0.079290      0.072934  ...           0.333437    282.193416
# min      150.648652    -34.113704  ...           0.000000      0.000000
# 25%      151.184637    -33.897568  ...           0.000000     80.000000
# 50%      151.223510    -33.882906  ...           0.000000    135.000000
# 75%      151.265703    -33.830692  ...           0.000000    229.000000
# max      151.339811    -33.400157  ...           1.000000  12999.000000
#
# [8 rows x 15 columns]

# %% [markdown]
# airbnb["city"] = airbnb["city"].astype('category')
# airbnb.dtypes

# %% [markdown]
# airbnb["city_cat"] = airbnb["city"].cat.codes
# airbnb.head(30)

# %%
# Data for Simple Linear Regression
from sklearn.model_selection import train_test_split

y = airbnb["price"]
X = airbnb.drop(["price"], axis=1)

X = X.drop(["city", "accommodates", "longitude", "latitude", "review_scores_rating", "number_of_reviews", "cleaning_fee", "bathrooms", "bedrooms", "beds", "property_type", "room_type", "availability_365", "host_identity_verified", "minimum_nights", "host_is_superhost", "cancellation_policy"], axis=1)

X.head()
# Out:
#    security_deposit
# 0                 0
# 1               300
# 2                 0
# 3               150
# 4              5000

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=42)

# %% [markdown]
# City_train = X_train.drop(["city", "longitude", "latitude", "review_scores_rating", "number_of_reviews", "security_deposit", "cleaning_fee", "accommodates", "bathrooms", "bedrooms", "beds", "property_type", "room_type", "availability_365", "host_identity_verified", "host_is_superhost", "cancellation_policy"], axis=1)

# %%
from sklearn.linear_model import LinearRegression

# Simple Linear Regression to City
security_deposit_lr = LinearRegression()
security_deposit_lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Visualising the Linear Regression results

# Visual libraries
import plotly.graph_objs as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=X_train["security_deposit"], y=y_train, name='security_deposit train', mode='markers'))
fig.add_trace(go.Scatter(x=X_train["security_deposit"], y=security_deposit_lr.predict(X_train), mode='lines', name='security_deposit regression'))

fig.update_layout(xaxis={"title": "Security Deposit"},
                  yaxis={"title": "Preço"})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0e369c7f-d840-4bbf-b09f-149e4fadb4ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0e369c7f-d840-4bbf-b09f-149e4fadb4ca")) {
#                     Plotly.newPlot(
#                         '0e369c7f-d840-4bbf-b09f-149e4fadb4ca',
# ...

# %%
clf_score = security_deposit_lr.score(X_test,y_test)
pred_clf = security_deposit_lr.predict(X_test)
print("Regression Model Score is : ", round(clf_score*100))
# Out:
# Regression Model Score is :  17

# %%
airbnb = airbnb.drop(5005)
